# %% [markdown]
# ## 2. Получение предсказаний на тестовой выборке и создание файла для kaggle.

# %% [markdown]
# Считаем данные из яндекс-диска

# %%
import os
import pandas as pd
path = r'/Users/adilkhankussidenov/Documents/github.com/kaggledata' 
data = {}

Data = []
Target = []



i=0
for dir_entry in sorted(os.listdir(path)):
    dir_entry_path = os.path.join(path, dir_entry)
    if os.path.isfile(dir_entry_path):
        i+=1
        with open(dir_entry_path, 'r') as my_file:
            print(dir_entry_path.split("\\")[-1])
            try:
                df = pd.read_csv(my_file, delimiter=';')
                if df.shape[1] == 5:
                    Data.append(df)
                    Target.append(dir_entry_path.split("\\")[-1])
            except UnicodeDecodeError:
                print(dir_entry_path.split("\\")[-1])
                pass

for dir_entry in sorted(os.listdir(path)):
    dir_entry_path = os.path.join(path, dir_entry)
    if os.path.isfile(dir_entry_path):
        i+=1
        with open(dir_entry_path, 'r') as my_file:
            print(dir_entry_path.split("\\")[-1])
            try:
                df = pd.read_csv(my_file, delimiter=',')
                if df.shape[1] == 5:
                    Data.append(df)
                    Target.append(dir_entry_path.split("\\")[-1])
            except UnicodeDecodeError:
                print(dir_entry_path.split("\\")[-1])
                pass
# Out:
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_0.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_1.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_10.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_100.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_101.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_102.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_103.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_104.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_105.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_106.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_107.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_108.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_109.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_11.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_110.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_111.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_112.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_113.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_114.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_115.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_116.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_117.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_118.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_119.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_12.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_120.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_121.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_122.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_123.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_124.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_125.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_126.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_127.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_128.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_129.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_13.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_130.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_131.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_132.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_133.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_134.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_135.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_136.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_137.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_138.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_139.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_14.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_140.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_141.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_142.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_143.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_144.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_145.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_15.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_16.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_17.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_18.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_19.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_2.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_20.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_21.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_22.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_23.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_24.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_25.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_26.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_27.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_28.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_29.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_3.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_30.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_31.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_32.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_33.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_34.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_35.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_36.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_37.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_38.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_39.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_4.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_40.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_41.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_42.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_43.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_44.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_45.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_46.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_47.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_48.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_49.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_5.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_50.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_51.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_52.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_53.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_54.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_55.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_56.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_57.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_58.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_59.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_6.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_60.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_61.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_62.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_63.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_64.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_65.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_66.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_67.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_68.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_69.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_7.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_70.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_71.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_72.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_73.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_74.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_75.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_76.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_77.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_78.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_79.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_8.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_80.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_81.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_82.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_83.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_84.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_85.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_86.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_87.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_88.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_89.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_9.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_90.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_91.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_92.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_93.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_94.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_95.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_96.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_97.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_98.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_99.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_0.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_1.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_10.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_100.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_101.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_102.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_103.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_104.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_105.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_106.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_107.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_108.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_109.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_11.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_110.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_111.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_112.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_113.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_114.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_115.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_116.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_117.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_118.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_119.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_12.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_120.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_121.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_122.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_123.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_124.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_125.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_126.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_127.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_128.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_129.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_13.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_130.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_131.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_132.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_133.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_134.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_135.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_136.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_137.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_138.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_139.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_14.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_140.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_141.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_142.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_143.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_144.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_145.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_15.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_16.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_17.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_18.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_19.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_2.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_20.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_21.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_22.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_23.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_24.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_25.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_26.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_27.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_28.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_29.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_3.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_30.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_31.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_32.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_33.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_34.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_35.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_36.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_37.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_38.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_39.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_4.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_40.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_41.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_42.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_43.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_44.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_45.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_46.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_47.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_48.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_49.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_5.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_50.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_51.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_52.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_53.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_54.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_55.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_56.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_57.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_58.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_59.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_6.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_60.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_61.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_62.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_63.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_64.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_65.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_66.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_67.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_68.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_69.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_7.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_70.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_71.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_72.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_73.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_74.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_75.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_76.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_77.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_78.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_79.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_8.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_80.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_81.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_82.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_83.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_84.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_85.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_86.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_87.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_88.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_89.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_9.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_90.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_91.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_92.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_93.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_94.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_95.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_96.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_97.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_98.csv
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_99.csv

# %% [markdown]
# Переведём типы движений в числа

# %%
classes = {'тояни' : 0, 'месте' : 0, 'одьб' : 1, 'аг' : 1, 'ег' : 2, 'елоси' : 3, 'естн' : 4, 'одъ' : 4, 
           'втомо' : 5, 'ашин' : 5, 'метро' : 6, 'лектро' : 7, 'амок' : 8}

answers = {'стояние' : 0, 'ходьба' : 1, 'бег' : 2, 'велосипед' : 3, 'лестница' : 4, 
           'автомобиль' : 5, 'метро' : 6, 'электросамокат' : 7, 'самокат' : 8}

# стояние, ходьба, велосипед, лестница, бег, подъем, подъём, автомобиль, электросамокат, машина, метро

# %%
def get_action(name):
    for act in classes:
        if name.lower().find(act) != -1:
            return classes[act]
    return -1

# %% [markdown]
# Обработаем данные и извлечём признаки для создания модели

# %%
import pandas as pd
from matplotlib import pylab as plt
# %pylab inline

def process_data(df, comma=True, cut=True, name = "", a=-1, b=-1):
    
# обрезаем начало и конец трека
    if a == -1:
        st = 1250
    else:
        st = a
            
    if b == -1:
        end = -1250
    else:
        end = b
        
    if cut == False:
        st = 0
        end = -1

    print(name)
#     fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, figsize=(15,6))

# приводим данные с Iphone к нужному формату
    if comma is True:
        df = df.applymap(lambda x: str(x).replace(',','.'))
        
        try:
            df['gFx'] = df['gFx'].astype(float)
            df['gFy'] = df['gFy'].astype(float)
            df['gFz'] = df['gFz'].astype(float)
        except KeyError:
            return -1

# рисуем графики ускорений
#     if cut:
#         ax1.plot(df.iloc[st:end]['gFx'],c='g')
#         ax1.plot(df.iloc[st:end]['gFy'],c='r')
#         ax1.plot(df.iloc[st:end]['gFz'],c='b')
#     else:
#         ax1.plot(df['gFx'],c='g')
#         ax1.plot(df['gFy'],c='r')
#         ax1.plot(df['gFz'],c='b')
        
# вычисляем модуль (норму) ускорения и рисуем его
    Acc = (df.gFx[st:end] ** 2 + df.gFy[st:end] ** 2 + df.gFz[st:end] ** 2) ** 0.5
#     ax2.plot(Acc)
#     plt.show()

# можно различить многие действия по амплитуде ускорения
    amplitude = Acc.max() - Acc.min()
    print(' АМПЛИТУДА:', Acc.max()-Acc.min())
    print()
    
    return amplitude

Ampl = np.zeros(len(Data)) 

for df, target in zip(Data,Target):
    #print(target.split('_')[1].split('.')[0])
    track_num = int(target.split('_')[1].split('.')[0]) # важный момент, что треки не по нумерации идут!
    Ampl[track_num] = process_data(df, name=target)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_0.csv
#  АМПЛИТУДА: 1.2409331302405158
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_1.csv
#  АМПЛИТУДА: 1.9935598883036225
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_10.csv
#  АМПЛИТУДА: 7.802304392990605
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_100.csv
#  АМПЛИТУДА: 0.34113272676839523
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_101.csv
#  АМПЛИТУДА: 0.4539765748076482
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_68.csv
#  АМПЛИТУДА: 2.407250674120206
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_69.csv
#  АМПЛИТУДА: 1.212572525596172
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_7.csv
#  АМПЛИТУДА: 9.43369600102802
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_70.csv
#  АМПЛИТУДА: 0.06644780954833251
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_71.csv
#  АМПЛИТУДА: 0.5116359327501921
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_72.csv
#  АМПЛИТУДА: 4.351635719111044
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_73.csv
#  АМПЛИТУДА: 2.1336461804594
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_74.csv
#  АМПЛИТУДА: 3.301098397972242
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_75.csv
#  АМПЛИТУДА: 7.158302893444175
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_76.csv
#  АМПЛИТУДА: 9.216037535513616
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_77.csv
#  АМПЛИТУДА: 1.8330376632404348
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_78.csv
#  АМПЛИТУДА: 2.76747032033991
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_79.csv
#  АМПЛИТУДА: 10.731937096693194
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_8.csv
#  АМПЛИТУДА: 0.9393878301836882
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_80.csv
#  АМПЛИТУДА: 1.633777351071156
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_81.csv
#  АМПЛИТУДА: 1.7316058352812163
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_82.csv
#  АМПЛИТУДА: 1.1505238336426609
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_83.csv
#  АМПЛИТУДА: 2.0522956446526943
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_84.csv
#  АМПЛИТУДА: 1.5829736314222569
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_85.csv
#  АМПЛИТУДА: 10.366406365305139
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_86.csv
#  АМПЛИТУДА: 6.151439856806816
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_87.csv
#  АМПЛИТУДА: 2.288305098772688
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_88.csv
#  АМПЛИТУДА: 4.103372254867931
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_89.csv
#  АМПЛИТУДА: 7.956676829256679
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_9.csv
#  АМПЛИТУДА: 0.0754719928206189
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_90.csv
#  АМПЛИТУДА: 0.025694414883784766
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_91.csv
#  АМПЛИТУДА: nan
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_92.csv
#  АМПЛИТУДА: 0.3402407681738169
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_93.csv
#  АМПЛИТУДА: 1.0520805860431857
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_94.csv
#  АМПЛИТУДА: 1.7141168789189019
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_95.csv
#  АМПЛИТУДА: 2.4909275186310906
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_96.csv
#  АМПЛИТУДА: 7.956676829256679
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_97.csv
#  АМПЛИТУДА: 3.0087221132495734
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_98.csv
#  АМПЛИТУДА: 0.3832853345388927
#
# /Users/adilkhankussidenov/Documents/github.com/kaggledata/track_99.csv
#  АМПЛИТУДА: 1.4788910252921896

# %% [markdown]
# Напишем функцию для получения предсказания (здесь используется только амплитуда, но в вашем итоговом решении будет больше признаков)

# %%
def get_prediction(ampl):
    if ampl < 1:
        return 0 #стояние
    if ampl >  5:
        return 2 #бег
    return 1 #ходьба

# %%
len(Data), len(Ampl), len(Target)
# Out:
# (146, 146, 146)

# %%
type(Data)
# Out:
# list

# %%
Ampl_new = []

i=0
for elem in Ampl:
    if not (math.isnan(elem) or elem == -1):
        i+=1
        Ampl_new.append(elem)
    else:
        Ampl_new.append(2)
len(Ampl_new), i
# Out:
# (146, 140)

# %% [markdown]
# Создадим таблицу, содержащую номер трека и предсказание.

# %%
prediction = [get_prediction(a) for a in Ampl]

Res = pd.DataFrame({'track_num' : np.arange(len(Data)), 'action' : prediction})
Res.head(10)
# Out:
#    track_num  action
# 0          0       1
# 1          1       1
# 2          2       1
# 3          3       2
# 4          4       1
# 5          5       1
# 6          6       1
# 7          7       2
# 8          8       0
# 9          9       0

# %%
Res.to_csv("first_submit.csv", index=False)
